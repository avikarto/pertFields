# %%
from plottingModule import plot3dWaist, plot2dWaist, plot1dWaist

# %%
plot1dWaist(field_type_index=3)  # E_z

# %%
plot2dWaist(field_type_index=0)  # phasor

# %%
plot3dWaist(field_type_index=3)  # E_z
